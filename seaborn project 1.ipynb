# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("accident.csv")
df
# Out:
#      Age  Gender  Speed_of_Impact  Helmet_Used  Seatbelt_Used  Survived
# 0     56       0               27            0              0         1
# 1     69       0               46            0              1         1
# 2     46       1               46            1              1         0
# 3     32       1              117            0              1         0
# 4     60       0               40            1              1         0
# ..   ...     ...              ...          ...            ...       ...
# 195   69       0              111            0              1         1
# 196   30       0               51            0              1         1
# 197   58       1              110            0              1         1
# 198   20       1              103            0              1         1
# 199   56       0               43            0              1         1
#
# [200 rows x 6 columns]

# %% [markdown]
# ### Isna,Dtypes,Describe,columns

# %%
df.isna().sum()
# Out:
# Age                0
# Gender             0
# Speed_of_Impact    0
# Helmet_Used        0
# Seatbelt_Used      0
# Survived           0
# dtype: int64

# %%
df.dtypes
# Out:
# Age                int64
# Gender             int64
# Speed_of_Impact    int64
# Helmet_Used        int64
# Seatbelt_Used      int64
# Survived           int64
# dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Age  Gender  Speed_of_Impact  Helmet_Used  Seatbelt_Used  Survived
# 0     56       0               27            0              0         1
# 1     69       0               46            0              1         1
# 2     46       1               46            1              1         0
# 3     32       1              117            0              1         0
# 4     60       0               40            1              1         0
# ..   ...     ...              ...          ...            ...       ...
# 195   69       0              111            0              1         1
# 196   30       0               51            0              1         1
# 197   58       1              110            0              1         1
# 198   20       1              103            0              1         1
# 199   56       0               43            0              1         1
#
# [200 rows x 6 columns]>

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Speed_of_Impact', 'Helmet_Used', 'Seatbelt_Used',
#        'Survived'],
#       dtype='object')

# %% [markdown]
# ### Fillna

# %%
df['Gender'].fillna('Female',inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_3808\1796177396.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].fillna('Female',inplace=True)

# %%
df['Speed_of_Impact'].fillna(df['Speed_of_Impact'].mean(),inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_3808\4225121950.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Speed_of_Impact'].fillna(df['Speed_of_Impact'].mean(),inplace=True)

# %%
df.isna().sum()
# Out:
# Age                0
# Gender             0
# Speed_of_Impact    0
# Helmet_Used        0
# Seatbelt_Used      0
# Survived           0
# dtype: int64

# %%
df['Speed_of_Impact']=df['Speed_of_Impact'].astype(int)

# %%
df.dtypes
# Out:
# Age                int64
# Gender             int64
# Speed_of_Impact    int32
# Helmet_Used        int64
# Seatbelt_Used      int64
# Survived           int64
# dtype: object

# %% [markdown]
# ## Seaborn Graphs

# %% [markdown]
# ### Histogram

# %%
sns.histplot(data=df,x='Speed_of_Impact',stat='frequency',kde=True)
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
sns.scatterplot(data=df,x='Age',y='Speed_of_Impact',hue='Gender')
plt.show()

# %% [markdown]
# ### Barplot

# %%
sns.barplot(x='Gender',y='Speed_of_Impact',data=df,hue='Helmet_Used',color='skyblue',saturation=0.9)
plt.xlabel("Gender")
plt.ylabel("speed of impact")
plt.title("Relationship between Gender and speed of impact ")
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_3808\3148277488.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:skyblue'` for the same effect.
#
#   sns.barplot(x='Gender',y='Speed_of_Impact',data=df,hue='Helmet_Used',color='skyblue',saturation=0.9)

# %%
sns.barplot(x='Helmet_Used',y='Age',data=df,hue='Gender',ci=None,palette='muted',saturation=0.9)
plt.xlabel("Helmet_used")
plt.ylabel("Age")
plt.title("Relationship between Age and Helmet Used ")
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_3808\2806079777.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Helmet_Used',y='Age',data=df,hue='Gender',ci=None,palette='muted',saturation=0.9)

# %%
sns.barplot(x='Helmet_Used',y='Speed_of_Impact',data=df,hue='Gender',color='lightgreen',saturation=0.9)
plt.xlabel("Helmet_used")
plt.ylabel("Speed of impact")
plt.title("Relationship between Speed of impact and Helmet Used ")
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_3808\2859526593.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:lightgreen'` for the same effect.
#
#   sns.barplot(x='Helmet_Used',y='Speed_of_Impact',data=df,hue='Gender',color='lightgreen',saturation=0.9)

# %% [markdown]
# ### Countplot

# %%
sns.countplot(x='Gender',data=df)
plt.show()

# %%
sns.countplot(x='Helmet_Used',data=df,facecolor='hotpink',edgecolor='black')
plt.show()

# %%
sns.countplot(x='Seatbelt_Used',data=df,facecolor='red',edgecolor='black')
plt.show()

# %%
sns.countplot(x='Survived',data=df,facecolor='lightgreen',edgecolor='black')
plt.show()

# %% [markdown]
# ### Swarmplot and Stripplot

# %%
sns.swarmplot(x='Gender',y='Speed_of_Impact',data=df)
plt.show()

# %%
sns.swarmplot(x='Seatbelt_Used',y='Speed_of_Impact',data=df,hue='Gender')
plt.show()

# %%
sns.stripplot(x='Survived',y='Speed_of_Impact',data=df,hue='Gender')
plt.show()

# %% [markdown]
# ### Boxplot and Violinplot

# %%
sns.boxplot(x='Gender',y='Speed_of_Impact',hue='Gender',showmeans=True,data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Speed_of_Impact'>

# %%
sns.violinplot(x='Gender',y='Speed_of_Impact',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Speed_of_Impact'>

# %% [markdown]
# ### KDEplot and Regression plot

# %%
sns.kdeplot(data=df,x='Age',y='Speed_of_Impact',shade=True,color='skyblue')
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_3808\4029051533.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df,x='Age',y='Speed_of_Impact',shade=True,color='skyblue')

# %%
sns.regplot(data=df,x='Age',y='Speed_of_Impact')
plt.show()

# %% [markdown]
# ### Pairplot and Jointplot

# %%
sns.pairplot(df)

# %%
sns.jointplot(data=df,x='Age',y='Speed_of_Impact',kind='scatter')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for column in ['Gender','Helmet_Used','Seatbelt_Used']:
    df[column]=le.fit_transform(df[column])

# %%
df
# Out:
#      Age  Gender  Speed_of_Impact  Helmet_Used  Seatbelt_Used  Survived
# 0     56       0               27            0              0         1
# 1     69       0               46            0              1         1
# 2     46       1               46            1              1         0
# 3     32       1              117            0              1         0
# 4     60       0               40            1              1         0
# ..   ...     ...              ...          ...            ...       ...
# 195   69       0              111            0              1         1
# 196   30       0               51            0              1         1
# 197   58       1              110            0              1         1
# 198   20       1              103            0              1         1
# 199   56       0               43            0              1         1
#
# [200 rows x 6 columns]

# %%
corr=df.corr()
corr
# Out:
#                       Age    Gender  Speed_of_Impact  Helmet_Used  \
# Age              1.000000 -0.055910         0.106628     0.094387
# Gender          -0.055910  1.000000        -0.047810     0.032493
# Speed_of_Impact  0.106628 -0.047810         1.000000    -0.010892
# Helmet_Used      0.094387  0.032493        -0.010892     1.000000
# Seatbelt_Used   -0.006868 -0.068732         0.000241     0.088977
# Survived         0.110090  0.121845         0.042274    -0.041353
#
#                  Seatbelt_Used  Survived
# Age                  -0.006868  0.110090
# Gender               -0.068732  0.121845
# Speed_of_Impact       0.000241  0.042274
# Helmet_Used           0.088977 -0.041353
# Seatbelt_Used         1.000000  0.059263
# Survived              0.059263  1.000000

# %% [markdown]
# ### Heatmap

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
df.to_csv('accident.csv',index=False)

# %%
p=pd.read_csv('accident.csv')
p
# Out:
#      Age  Gender  Speed_of_Impact  Helmet_Used  Seatbelt_Used  Survived
# 0     56       0               27            0              0         1
# 1     69       0               46            0              1         1
# 2     46       1               46            1              1         0
# 3     32       1              117            0              1         0
# 4     60       0               40            1              1         0
# ..   ...     ...              ...          ...            ...       ...
# 195   69       0              111            0              1         1
# 196   30       0               51            0              1         1
# 197   58       1              110            0              1         1
# 198   20       1              103            0              1         1
# 199   56       0               43            0              1         1
#
# [200 rows x 6 columns]
